# %% [markdown]
# <a href="https://colab.research.google.com/github/thanawat150/EnglishTest/blob/main/geoai-excercises/lec3/CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Download the data

# %%
# !mkdir Dataset
# !wget  https://zenodo.org/records/7189381/files/trainX.npy?download=1  -O Dataset/Xdata.npy
# !wget  https://zenodo.org/records/7189381/files/trainY.npy?download=1  -O Dataset/Ydata.npy
# Out:
# --2025-08-27 01:09:15--  https://zenodo.org/records/7189381/files/trainX.npy?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.48.194, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 293339264 (280M) [application/octet-stream]
# Saving to: ‘Dataset/Xdata.npy’
#
# Dataset/Xdata.npy   100%[===================>] 279.75M  2.72MB/s    in 6m 36s
#
# 2025-08-27 01:15:52 (723 KB/s) - ‘Dataset/Xdata.npy’ saved [293339264/293339264]
#
# --2025-08-27 01:15:52--  https://zenodo.org/records/7189381/files/trainY.npy?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.43.25, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 73334912 (70M) [application/octet-stream]
# Saving to: ‘Dataset/Ydata.npy’
#
# Dataset/Ydata.npy   100%[===================>]  69.94M  2.19MB/s    in 56s
#
# 2025-08-27 01:16:49 (1.25 MB/s) - ‘Dataset/Ydata.npy’ saved [73334912/73334912]

# %% [markdown]
# ## Prepare paths of input images and target segmentation masks

# %%
import numpy as np #numpy numerical python
import tensorflow as tf # tensorflow it is mostly used for deep learning tensor manipulation
import keras # backend of tensorflow
import matplotlib.pyplot as plt # plotting
from sklearn.model_selection import train_test_split # split the dtaset into training and test
import sklearn # Accuracy assessment,
from tensorflow.keras import models
from tensorflow.keras.layers import *
from tensorflow.keras.activations import *
from tensorflow.keras.models import Sequential

# %%
Xdata = np.load("Dataset/Xdata.npy")
Ydata = np.load("Dataset/Ydata.npy")
print(f"the shape of input image matrix is {Xdata.shape}")
# Out:
# the shape of input image matrix is (1119, 128, 128, 4)

# %% [markdown]
# ## What does one input image and corresponding segmentation mask look like?

# %%
n = 289  # sample number
fig, ax = plt.subplots(1, 2, figsize=(12, 6)) # making a subplot of 1 row 2 columns
ax[0].imshow(Xdata[n, :, :, :3].transpose((0, 1, 2))) #satellite image
ax[1].imshow(Ydata[n, :, :, 0]) #Ground Truth

ax[0].ticklabel_format(useOffset=False, style="plain")
ax[1].ticklabel_format(useOffset=False, style="plain")

# %% [markdown]
# ## Prepare dataset to train validate and test the model

# %%
X_train, X_test, y_train, y_test = train_test_split(
    Xdata, Ydata, test_size=0.3, random_state=42
)

# %% [markdown]
# ## Prepare U-Net model

# %%
def down_block(x, filters, use_maxpool=True): # Function for down block
    x = Conv2D(filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2D(filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    if use_maxpool == True:
        return MaxPooling2D(strides=(2, 2))(x), x
    else:
        return x


def up_block(x, y, filters):
    x = UpSampling2D()(x)
    x = Concatenate(axis=3)([x, y])
    x = Conv2D(filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    # in the second convolution layer in decoder we do not
    #  need to upsample or concatenate because it has been done already
    x = Conv2D(filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    # No max pooling because we do not need to decrease the size

    return x


def get_model(input_size=(128, 128, 4), *, classes, dropout):
    filter = [64, 128, 256, 512, 1024]
    # encode
    input = Input(shape=input_size)
    x, temp1 = down_block(input, filter[0]) #Calling the function
    x, temp2 = down_block(x, filter[1])
    x, temp3 = down_block(x, filter[2])
    x, temp4 = down_block(x, filter[3])
    x = down_block(x, filter[4], use_maxpool=False)
    # decode
    x = up_block(x, temp4, filter[3])
    x = up_block(x, temp3, filter[2])
    x = up_block(x, temp2, filter[1])
    x = up_block(x, temp1, filter[0])
    x = Dropout(dropout)(x)

    output = Conv2D(classes, 1, activation="sigmoid")(x)


    model = models.Model(input, output, name="unet")
    model.summary()
    return model


# Build model
model = get_model(input_size=(128, 128, 4), classes=1, dropout=0.2)
model.summary()
# Out:
# Model: "unet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │      2,368 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │     36,928 │ leaky_re_lu[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ leaky_re_lu_1[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │    147,584 │ leaky_re_lu_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ leaky_re_lu_3[0]… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    590,080 │ leaky_re_lu_4[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ leaky_re_lu_5[0]… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_6       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ leaky_re_lu_6[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_7       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 512) │          0 │ leaky_re_lu_7[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8,      │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_8       │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8,      │  9,438,208 │ leaky_re_lu_8[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_9       │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 16, 16,    │          0 │ leaky_re_lu_9[0]… │
# │ (UpSampling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 1536)             │            │ leaky_re_lu_7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │  7,078,400 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ leaky_re_lu_10[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 32, 32,    │          0 │ leaky_re_lu_11[0… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 768)              │            │ leaky_re_lu_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │  1,769,728 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │    590,080 │ leaky_re_lu_12[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 64, 64,    │          0 │ leaky_re_lu_13[0… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 384)              │            │ leaky_re_lu_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 64, 64,    │    442,496 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_14      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 64, 64,    │    147,584 │ leaky_re_lu_14[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 128, 128,  │          0 │ leaky_re_lu_15[0… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 192)              │            │ leaky_re_lu_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 128, 128,  │    110,656 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_16      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │     36,928 │ leaky_re_lu_16[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_17      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ leaky_re_lu_17[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 128, 128,  │         65 │ dropout[0][0]     │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,403,073 (119.79 MB)
#  Trainable params: 31,391,297 (119.75 MB)
#  Non-trainable params: 11,776 (46.00 KB)
# Model: "unet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │      2,368 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │     36,928 │ leaky_re_lu[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ leaky_re_lu_1[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │    147,584 │ leaky_re_lu_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ leaky_re_lu_3[0]… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    590,080 │ leaky_re_lu_4[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ leaky_re_lu_5[0]… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_6       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ leaky_re_lu_6[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_7       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 512) │          0 │ leaky_re_lu_7[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8,      │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_8       │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8,      │  9,438,208 │ leaky_re_lu_8[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_9       │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 16, 16,    │          0 │ leaky_re_lu_9[0]… │
# │ (UpSampling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 1536)             │            │ leaky_re_lu_7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │  7,078,400 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ leaky_re_lu_10[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 32, 32,    │          0 │ leaky_re_lu_11[0… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 768)              │            │ leaky_re_lu_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │  1,769,728 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │    590,080 │ leaky_re_lu_12[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 64, 64,    │          0 │ leaky_re_lu_13[0… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 384)              │            │ leaky_re_lu_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 64, 64,    │    442,496 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_14      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 64, 64,    │    147,584 │ leaky_re_lu_14[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 128, 128,  │          0 │ leaky_re_lu_15[0… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 192)              │            │ leaky_re_lu_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 128, 128,  │    110,656 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_16      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │     36,928 │ leaky_re_lu_16[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_17      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ leaky_re_lu_17[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 128, 128,  │         65 │ dropout[0][0]     │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,403,073 (119.79 MB)
#  Trainable params: 31,391,297 (119.75 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %% [markdown]
# ## Train the model

# %% [markdown]
# keras API https://keras.io/api/layers/regularizers/
#
# WorldCereal https://esa-worldcereal.org/en/products/crop-calendars
#
# WorldCereal Process http://hub.esa-worldcereal.org/process-list

# %%
# Compile model for training
model.compile(
    optimizer=keras.optimizers.Adam(1e-4),
    loss="binary_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.AUC(),
        tf.keras.metrics.MeanIoU(num_classes=2),
        tf.keras.metrics.Precision(),
        tf.keras.metrics.Recall(),
    ],
)


def trainmodel(model, xdata, ydata):
    NUMBER_EPOCHS = 100
    filepath = "checkpointMaping.keras"
    BATCH_SIZE = 32

    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath,
        monitor="val_loss",
        verbose=0,
        save_best_only=True,
        save_weights_only=False,
        mode="min",
        save_freq="epoch"
    )
    print(type(xdata), type(ydata))
    hist = model.fit(
        x=xdata,
        y=ydata,
        epochs=NUMBER_EPOCHS,
        batch_size=BATCH_SIZE,
        validation_split=0.2,  # auto validate using 20% of random samples at each epoch
        verbose=1,
        callbacks=[model_checkpoint_callback],

    )
    return hist

# %%
trainmodel(
    model,
    np.array(X_train, dtype=np.float32),
    np.expand_dims(np.array(y_train, dtype=np.float32), axis=-1),
)
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.9378 - auc_1: 0.9430 - loss: 0.1919 - mean_io_u_1: 0.4580 - precision_1: 0.6992 - recall_1: 0.6522 - val_accuracy: 0.8926 - val_auc_1: 0.8351 - val_loss: 0.3556 - val_mean_io_u_1: 0.4455 - val_precision_1: 0.9686 - val_recall_1: 0.0152
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 624ms/step - accuracy: 0.9407 - auc_1: 0.9445 - loss: 0.1877 - mean_io_u_1: 0.4508 - precision_1: 0.7095 - recall_1: 0.6782 - val_accuracy: 0.8935 - val_auc_1: 0.8730 - val_loss: 0.2903 - val_mean_io_u_1: 0.4455 - val_precision_1: 0.5238 - val_recall_1: 0.2549
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 615ms/step - accuracy: 0.9363 - auc_1: 0.9470 - loss: 0.1851 - mean_io_u_1: 0.4512 - precision_1: 0.6818 - recall_1: 0.6942 - val_accuracy: 0.9064 - val_auc_1: 0.9119 - val_loss: 0.2404 - val_mean_io_u_1: 0.4457 - val_precision_1: 0.9006 - val_recall_1: 0.1591
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 633ms/step - accuracy: 0.9431 - auc_1: 0.9515 - loss: 0.1709 - mean_io_u_1: 0.4552 - precision_1: 0.7289 - recall_1: 0.6878 - val_accuracy: 0.9088 - val_auc_1: 0.9088 - val_loss: 0.2240 - val_mean_io_u_1: 0.4455 - val_precision_1: 0.7059 - val_recall_1: 0.2799
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 13s 645ms/step - accuracy: 0.9385 - auc_1: 0.9481 - loss: 0.1759 - mean_io_u_1: 0.4483 - precision_1: 0.7422 - recall_1: 0.6776 - val_accuracy: 0.9159 - val_auc_1: 0.8923 - val_loss: 0.2230 - val_mean_io_u_1: 0.4465 - val_precision_1: 0.7284 - val_recall_1: 0.3652
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 534ms/step - accuracy: 0.9470 - auc_1: 0.9588 - loss: 0.1592 - mean_io_u_1: 0.4551 - precision_1: 0.7666 - recall_1: 0.7066 - val_accuracy: 0.9117 - val_auc_1: 0.9220 - val_loss: 0.2441 - val_mean_io_u_1: 0.4476 - val_precision_1: 0.6592 - val_recall_1: 0.3942
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 520ms/step - accuracy: 0.9471 - auc_1: 0.9592 - loss: 0.1555 - mean_io_u_1: 0.4586 - precision_1: 0.7618 - recall_1: 0.6945 - val_accuracy: 0.9095 - val_auc_1: 0.9303 - val_loss: 0.2258 - val_mean_io_u_1: 0.4465 - val_precision_1: 0.8136 - val_recall_1: 0.2202
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 532ms/step - accuracy: 0.9429 - auc_1: 0.9577 - loss: 0.1632 - mean_io_u_1: 0.4548 - precision_1: 0.7492 - recall_1: 0.6882 - val_accuracy: 0.9062 - val_auc_1: 0.9244 - val_loss: 0.2455 - val_mean_io_u_1: 0.4455 - val_precision_1: 0.8412 - val_recall_1: 0.1728
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 873ms/step - accuracy: 0.9443 - auc_1: 0.9609 - loss: 0.1584 - mean_io_u_1: 0.4471 - precision_1: 0.7751 - recall_1: 0.7062 - val_accuracy: 0.9224 - val_auc_1: 0.9363 - val_loss: 0.1989 - val_mean_io_u_1: 0.4476 - val_precision_1: 0.8734 - val_recall_1: 0.3375
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 513ms/step - accuracy: 0.9456 - auc_1: 0.9592 - loss: 0.1548 - mean_io_u_1: 0.4548 - precision_1: 0.7787 - recall_1: 0.6639 - val_accuracy: 0.7905 - val_auc_1: 0.8256 - val_loss: 0.6128 - val_mean_io_u_1: 0.4504 - val_precision_1: 0.3016 - val_recall_1: 0.7004
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 13s 654ms/step - accuracy: 0.9420 - auc_1: 0.9515 - loss: 0.1756 - mean_io_u_1: 0.4549 - precision_1: 0.7389 - recall_1: 0.6883 - val_accuracy: 0.9323 - val_auc_1: 0.9237 - val_loss: 0.1960 - val_mean_io_u_1: 0.4495 - val_precision_1: 0.7462 - val_recall_1: 0.5750
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 634ms/step - accuracy: 0.9444 - auc_1: 0.9573 - loss: 0.1599 - mean_io_u_1: 0.4528 - precision_1: 0.7560 - recall_1: 0.6961 - val_accuracy: 0.9340 - val_auc_1: 0.9517 - val_loss: 0.1751 - val_mean_io_u_1: 0.4491 - val_precision_1: 0.7818 - val_recall_1: 0.5479
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 628ms/step - accuracy: 0.9459 - auc_1: 0.9592 - loss: 0.1533 - mean_io_u_1: 0.4546 - precision_1: 0.7469 - recall_1: 0.7088 - val_accuracy: 0.9372 - val_auc_1: 0.9615 - val_loss: 0.1610 - val_mean_io_u_1: 0.4457 - val_precision_1: 0.7851 - val_recall_1: 0.5844
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 539ms/step - accuracy: 0.9465 - auc_1: 0.9626 - loss: 0.1493 - mean_io_u_1: 0.4516 - precision_1: 0.7452 - recall_1: 0.7118 - val_accuracy: 0.9208 - val_auc_1: 0.9052 - val_loss: 0.2102 - val_mean_io_u_1: 0.4458 - val_precision_1: 0.7525 - val_recall_1: 0.4080
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 521ms/step - accuracy: 0.9478 - auc_1: 0.9625 - loss: 0.1459 - mean_io_u_1: 0.4521 - precision_1: 0.7777 - recall_1: 0.6911 - val_accuracy: 0.9386 - val_auc_1: 0.9616 - val_loss: 0.1700 - val_mean_io_u_1: 0.4569 - val_precision_1: 0.7337 - val_recall_1: 0.6852
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 642ms/step - accuracy: 0.9523 - auc_1: 0.9691 - loss: 0.1348 - mean_io_u_1: 0.4531 - precision_1: 0.8026 - recall_1: 0.7369 - val_accuracy: 0.9401 - val_auc_1: 0.9654 - val_loss: 0.1571 - val_mean_io_u_1: 0.4488 - val_precision_1: 0.7528 - val_recall_1: 0.6713
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 521ms/step - accuracy: 0.9533 - auc_1: 0.9679 - loss: 0.1344 - mean_io_u_1: 0.4552 - precision_1: 0.8152 - recall_1: 0.7124 - val_accuracy: 0.9373 - val_auc_1: 0.9600 - val_loss: 0.1598 - val_mean_io_u_1: 0.4470 - val_precision_1: 0.7399 - val_recall_1: 0.6559
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 530ms/step - accuracy: 0.9530 - auc_1: 0.9690 - loss: 0.1342 - mean_io_u_1: 0.4566 - precision_1: 0.8099 - recall_1: 0.7289 - val_accuracy: 0.9401 - val_auc_1: 0.9602 - val_loss: 0.1619 - val_mean_io_u_1: 0.4524 - val_precision_1: 0.7684 - val_recall_1: 0.6444
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 532ms/step - accuracy: 0.9518 - auc_1: 0.9708 - loss: 0.1327 - mean_io_u_1: 0.4587 - precision_1: 0.7929 - recall_1: 0.7475 - val_accuracy: 0.9397 - val_auc_1: 0.9669 - val_loss: 0.1578 - val_mean_io_u_1: 0.4523 - val_precision_1: 0.7260 - val_recall_1: 0.7180
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 532ms/step - accuracy: 0.9577 - auc_1: 0.9737 - loss: 0.1225 - mean_io_u_1: 0.4649 - precision_1: 0.8142 - recall_1: 0.7460 - val_accuracy: 0.9389 - val_auc_1: 0.9679 - val_loss: 0.1646 - val_mean_io_u_1: 0.4516 - val_precision_1: 0.7025 - val_recall_1: 0.7630
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 525ms/step - accuracy: 0.9537 - auc_1: 0.9749 - loss: 0.1277 - mean_io_u_1: 0.4580 - precision_1: 0.8031 - recall_1: 0.7799 - val_accuracy: 0.9324 - val_auc_1: 0.9628 - val_loss: 0.1804 - val_mean_io_u_1: 0.4544 - val_precision_1: 0.6700 - val_recall_1: 0.7488
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 525ms/step - accuracy: 0.9543 - auc_1: 0.9726 - loss: 0.1279 - mean_io_u_1: 0.4580 - precision_1: 0.8135 - recall_1: 0.7444 - val_accuracy: 0.9353 - val_auc_1: 0.9644 - val_loss: 0.1793 - val_mean_io_u_1: 0.4561 - val_precision_1: 0.6763 - val_recall_1: 0.7796
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 549ms/step - accuracy: 0.9551 - auc_1: 0.9727 - loss: 0.1261 - mean_io_u_1: 0.4564 - precision_1: 0.8332 - recall_1: 0.7228 - val_accuracy: 0.9359 - val_auc_1: 0.9599 - val_loss: 0.1762 - val_mean_io_u_1: 0.4593 - val_precision_1: 0.6953 - val_recall_1: 0.7335
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 529ms/step - accuracy: 0.9576 - auc_1: 0.9751 - loss: 0.1189 - mean_io_u_1: 0.4641 - precision_1: 0.8240 - recall_1: 0.7513 - val_accuracy: 0.9383 - val_auc_1: 0.9651 - val_loss: 0.1664 - val_mean_io_u_1: 0.4598 - val_precision_1: 0.7131 - val_recall_1: 0.7273
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 535ms/step - accuracy: 0.9609 - auc_1: 0.9779 - loss: 0.1129 - mean_io_u_1: 0.4657 - precision_1: 0.8245 - recall_1: 0.7951 - val_accuracy: 0.9351 - val_auc_1: 0.9562 - val_loss: 0.1691 - val_mean_io_u_1: 0.4516 - val_precision_1: 0.7540 - val_recall_1: 0.6014
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 524ms/step - accuracy: 0.9588 - auc_1: 0.9752 - loss: 0.1175 - mean_io_u_1: 0.4604 - precision_1: 0.8404 - recall_1: 0.7513 - val_accuracy: 0.9343 - val_auc_1: 0.9482 - val_loss: 0.1767 - val_mean_io_u_1: 0.4526 - val_precision_1: 0.7821 - val_recall_1: 0.5513
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 531ms/step - accuracy: 0.9596 - auc_1: 0.9744 - loss: 0.1160 - mean_io_u_1: 0.4538 - precision_1: 0.8434 - recall_1: 0.7690 - val_accuracy: 0.9393 - val_auc_1: 0.9656 - val_loss: 0.1597 - val_mean_io_u_1: 0.4546 - val_precision_1: 0.7714 - val_recall_1: 0.6305
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 546ms/step - accuracy: 0.9637 - auc_1: 0.9817 - loss: 0.1044 - mean_io_u_1: 0.4636 - precision_1: 0.8529 - recall_1: 0.7920 - val_accuracy: 0.9353 - val_auc_1: 0.9639 - val_loss: 0.1895 - val_mean_io_u_1: 0.4594 - val_precision_1: 0.6771 - val_recall_1: 0.7773
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 508ms/step - accuracy: 0.9675 - auc_1: 0.9834 - loss: 0.0963 - mean_io_u_1: 0.4746 - precision_1: 0.8407 - recall_1: 0.8250 - val_accuracy: 0.9383 - val_auc_1: 0.9632 - val_loss: 0.1712 - val_mean_io_u_1: 0.4565 - val_precision_1: 0.7240 - val_recall_1: 0.7012
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 533ms/step - accuracy: 0.9648 - auc_1: 0.9836 - loss: 0.0998 - mean_io_u_1: 0.4700 - precision_1: 0.8513 - recall_1: 0.8045 - val_accuracy: 0.9363 - val_auc_1: 0.9637 - val_loss: 0.1935 - val_mean_io_u_1: 0.4674 - val_precision_1: 0.6870 - val_recall_1: 0.7647
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 515ms/step - accuracy: 0.9647 - auc_1: 0.9821 - loss: 0.1018 - mean_io_u_1: 0.4717 - precision_1: 0.8360 - recall_1: 0.8154 - val_accuracy: 0.9384 - val_auc_1: 0.9619 - val_loss: 0.1675 - val_mean_io_u_1: 0.4542 - val_precision_1: 0.7511 - val_recall_1: 0.6501
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 533ms/step - accuracy: 0.9624 - auc_1: 0.9790 - loss: 0.1067 - mean_io_u_1: 0.4645 - precision_1: 0.8466 - recall_1: 0.8020 - val_accuracy: 0.9341 - val_auc_1: 0.9532 - val_loss: 0.1775 - val_mean_io_u_1: 0.4535 - val_precision_1: 0.7569 - val_recall_1: 0.5826
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 532ms/step - accuracy: 0.9667 - auc_1: 0.9842 - loss: 0.0949 - mean_io_u_1: 0.4744 - precision_1: 0.8590 - recall_1: 0.8153 - val_accuracy: 0.9385 - val_auc_1: 0.9612 - val_loss: 0.1808 - val_mean_io_u_1: 0.4657 - val_precision_1: 0.7459 - val_recall_1: 0.6610
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 513ms/step - accuracy: 0.9677 - auc_1: 0.9851 - loss: 0.0930 - mean_io_u_1: 0.4738 - precision_1: 0.8633 - recall_1: 0.8285 - val_accuracy: 0.9380 - val_auc_1: 0.9633 - val_loss: 0.1703 - val_mean_io_u_1: 0.4552 - val_precision_1: 0.7223 - val_recall_1: 0.7013
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 524ms/step - accuracy: 0.9702 - auc_1: 0.9868 - loss: 0.0869 - mean_io_u_1: 0.4783 - precision_1: 0.8695 - recall_1: 0.8292 - val_accuracy: 0.9365 - val_auc_1: 0.9654 - val_loss: 0.1984 - val_mean_io_u_1: 0.4778 - val_precision_1: 0.6859 - val_recall_1: 0.7702
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 521ms/step - accuracy: 0.9692 - auc_1: 0.9865 - loss: 0.0894 - mean_io_u_1: 0.4863 - precision_1: 0.8506 - recall_1: 0.8357 - val_accuracy: 0.9365 - val_auc_1: 0.9644 - val_loss: 0.1840 - val_mean_io_u_1: 0.4656 - val_precision_1: 0.6902 - val_recall_1: 0.7575
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 520ms/step - accuracy: 0.9727 - auc_1: 0.9901 - loss: 0.0795 - mean_io_u_1: 0.4843 - precision_1: 0.8725 - recall_1: 0.8560 - val_accuracy: 0.9364 - val_auc_1: 0.9551 - val_loss: 0.1795 - val_mean_io_u_1: 0.4611 - val_precision_1: 0.7328 - val_recall_1: 0.6561
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 535ms/step - accuracy: 0.9725 - auc_1: 0.9880 - loss: 0.0808 - mean_io_u_1: 0.4911 - precision_1: 0.8867 - recall_1: 0.8293 - val_accuracy: 0.9356 - val_auc_1: 0.9598 - val_loss: 0.1940 - val_mean_io_u_1: 0.4728 - val_precision_1: 0.6848 - val_recall_1: 0.7594
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 523ms/step - accuracy: 0.9745 - auc_1: 0.9909 - loss: 0.0754 - mean_io_u_1: 0.4941 - precision_1: 0.8685 - recall_1: 0.8632 - val_accuracy: 0.9364 - val_auc_1: 0.9585 - val_loss: 0.2056 - val_mean_io_u_1: 0.4904 - val_precision_1: 0.7076 - val_recall_1: 0.7107
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 518ms/step - accuracy: 0.9751 - auc_1: 0.9890 - loss: 0.0750 - mean_io_u_1: 0.5006 - precision_1: 0.8819 - recall_1: 0.8523 - val_accuracy: 0.9377 - val_auc_1: 0.9591 - val_loss: 0.1880 - val_mean_io_u_1: 0.4697 - val_precision_1: 0.7193 - val_recall_1: 0.7025
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 552ms/step - accuracy: 0.9740 - auc_1: 0.9913 - loss: 0.0754 - mean_io_u_1: 0.4965 - precision_1: 0.8766 - recall_1: 0.8670 - val_accuracy: 0.9382 - val_auc_1: 0.9604 - val_loss: 0.1850 - val_mean_io_u_1: 0.4679 - val_precision_1: 0.7393 - val_recall_1: 0.6691
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 529ms/step - accuracy: 0.9763 - auc_1: 0.9926 - loss: 0.0690 - mean_io_u_1: 0.4951 - precision_1: 0.8925 - recall_1: 0.8755 - val_accuracy: 0.9363 - val_auc_1: 0.9599 - val_loss: 0.1795 - val_mean_io_u_1: 0.4574 - val_precision_1: 0.7240 - val_recall_1: 0.6717
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 520ms/step - accuracy: 0.9743 - auc_1: 0.9920 - loss: 0.0727 - mean_io_u_1: 0.4869 - precision_1: 0.8967 - recall_1: 0.8628 - val_accuracy: 0.9340 - val_auc_1: 0.9511 - val_loss: 0.2062 - val_mean_io_u_1: 0.4780 - val_precision_1: 0.7131 - val_recall_1: 0.6604
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 507ms/step - accuracy: 0.9762 - auc_1: 0.9926 - loss: 0.0685 - mean_io_u_1: 0.4963 - precision_1: 0.8914 - recall_1: 0.8756 - val_accuracy: 0.9384 - val_auc_1: 0.9596 - val_loss: 0.1994 - val_mean_io_u_1: 0.4857 - val_precision_1: 0.7224 - val_recall_1: 0.7067
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 518ms/step - accuracy: 0.9786 - auc_1: 0.9936 - loss: 0.0631 - mean_io_u_1: 0.5084 - precision_1: 0.8955 - recall_1: 0.8865 - val_accuracy: 0.9378 - val_auc_1: 0.9513 - val_loss: 0.1964 - val_mean_io_u_1: 0.4697 - val_precision_1: 0.7325 - val_recall_1: 0.6773
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 537ms/step - accuracy: 0.9773 - auc_1: 0.9935 - loss: 0.0660 - mean_io_u_1: 0.5086 - precision_1: 0.8824 - recall_1: 0.8882 - val_accuracy: 0.9348 - val_auc_1: 0.9509 - val_loss: 0.2011 - val_mean_io_u_1: 0.4753 - val_precision_1: 0.7197 - val_recall_1: 0.6592
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 540ms/step - accuracy: 0.9779 - auc_1: 0.9932 - loss: 0.0644 - mean_io_u_1: 0.5126 - precision_1: 0.8979 - recall_1: 0.8825 - val_accuracy: 0.9355 - val_auc_1: 0.9553 - val_loss: 0.2239 - val_mean_io_u_1: 0.4927 - val_precision_1: 0.6977 - val_recall_1: 0.7206
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 519ms/step - accuracy: 0.9796 - auc_1: 0.9943 - loss: 0.0594 - mean_io_u_1: 0.5148 - precision_1: 0.9044 - recall_1: 0.8961 - val_accuracy: 0.9345 - val_auc_1: 0.9503 - val_loss: 0.2066 - val_mean_io_u_1: 0.4760 - val_precision_1: 0.7244 - val_recall_1: 0.6447
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 520ms/step - accuracy: 0.9796 - auc_1: 0.9944 - loss: 0.0594 - mean_io_u_1: 0.5155 - precision_1: 0.9211 - recall_1: 0.8862 - val_accuracy: 0.9370 - val_auc_1: 0.9462 - val_loss: 0.2088 - val_mean_io_u_1: 0.4850 - val_precision_1: 0.7567 - val_recall_1: 0.6225
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 520ms/step - accuracy: 0.9813 - auc_1: 0.9956 - loss: 0.0543 - mean_io_u_1: 0.5198 - precision_1: 0.9211 - recall_1: 0.8995 - val_accuracy: 0.9371 - val_auc_1: 0.9518 - val_loss: 0.2092 - val_mean_io_u_1: 0.4854 - val_precision_1: 0.7402 - val_recall_1: 0.6516
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 519ms/step - accuracy: 0.9798 - auc_1: 0.9951 - loss: 0.0574 - mean_io_u_1: 0.5139 - precision_1: 0.9160 - recall_1: 0.9048 - val_accuracy: 0.9356 - val_auc_1: 0.9545 - val_loss: 0.2294 - val_mean_io_u_1: 0.5040 - val_precision_1: 0.6955 - val_recall_1: 0.7289
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 520ms/step - accuracy: 0.9784 - auc_1: 0.9943 - loss: 0.0605 - mean_io_u_1: 0.5149 - precision_1: 0.9133 - recall_1: 0.8969 - val_accuracy: 0.9349 - val_auc_1: 0.9355 - val_loss: 0.2122 - val_mean_io_u_1: 0.4836 - val_precision_1: 0.7471 - val_recall_1: 0.6098
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 548ms/step - accuracy: 0.9827 - auc_1: 0.9961 - loss: 0.0507 - mean_io_u_1: 0.5312 - precision_1: 0.9298 - recall_1: 0.8950 - val_accuracy: 0.9375 - val_auc_1: 0.9485 - val_loss: 0.2177 - val_mean_io_u_1: 0.4940 - val_precision_1: 0.7405 - val_recall_1: 0.6568
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 529ms/step - accuracy: 0.9819 - auc_1: 0.9963 - loss: 0.0518 - mean_io_u_1: 0.5276 - precision_1: 0.9184 - recall_1: 0.9153 - val_accuracy: 0.9330 - val_auc_1: 0.9375 - val_loss: 0.2168 - val_mean_io_u_1: 0.4754 - val_precision_1: 0.7710 - val_recall_1: 0.5489
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 535ms/step - accuracy: 0.9819 - auc_1: 0.9956 - loss: 0.0521 - mean_io_u_1: 0.5319 - precision_1: 0.9250 - recall_1: 0.8974 - val_accuracy: 0.9347 - val_auc_1: 0.9587 - val_loss: 0.2726 - val_mean_io_u_1: 0.5304 - val_precision_1: 0.6813 - val_recall_1: 0.7541
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 542ms/step - accuracy: 0.9832 - auc_1: 0.9967 - loss: 0.0486 - mean_io_u_1: 0.5420 - precision_1: 0.9130 - recall_1: 0.9264 - val_accuracy: 0.9373 - val_auc_1: 0.9442 - val_loss: 0.2508 - val_mean_io_u_1: 0.5240 - val_precision_1: 0.7205 - val_recall_1: 0.6943
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 522ms/step - accuracy: 0.9825 - auc_1: 0.9962 - loss: 0.0501 - mean_io_u_1: 0.5381 - precision_1: 0.9252 - recall_1: 0.9067 - val_accuracy: 0.9349 - val_auc_1: 0.9450 - val_loss: 0.2453 - val_mean_io_u_1: 0.5093 - val_precision_1: 0.7093 - val_recall_1: 0.6826
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 537ms/step - accuracy: 0.9844 - auc_1: 0.9969 - loss: 0.0457 - mean_io_u_1: 0.5432 - precision_1: 0.9287 - recall_1: 0.9186 - val_accuracy: 0.9345 - val_auc_1: 0.9560 - val_loss: 0.2600 - val_mean_io_u_1: 0.5314 - val_precision_1: 0.6781 - val_recall_1: 0.7599
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 519ms/step - accuracy: 0.9849 - auc_1: 0.9972 - loss: 0.0443 - mean_io_u_1: 0.5479 - precision_1: 0.9226 - recall_1: 0.9289 - val_accuracy: 0.9349 - val_auc_1: 0.9541 - val_loss: 0.2654 - val_mean_io_u_1: 0.5265 - val_precision_1: 0.6873 - val_recall_1: 0.7390
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 546ms/step - accuracy: 0.9843 - auc_1: 0.9969 - loss: 0.0448 - mean_io_u_1: 0.5432 - precision_1: 0.9326 - recall_1: 0.9166 - val_accuracy: 0.9323 - val_auc_1: 0.9489 - val_loss: 0.2562 - val_mean_io_u_1: 0.5132 - val_precision_1: 0.6788 - val_recall_1: 0.7187
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 532ms/step - accuracy: 0.9853 - auc_1: 0.9974 - loss: 0.0425 - mean_io_u_1: 0.5525 - precision_1: 0.9440 - recall_1: 0.9169 - val_accuracy: 0.9359 - val_auc_1: 0.9509 - val_loss: 0.2582 - val_mean_io_u_1: 0.5313 - val_precision_1: 0.6998 - val_recall_1: 0.7212
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 535ms/step - accuracy: 0.9857 - auc_1: 0.9975 - loss: 0.0417 - mean_io_u_1: 0.5540 - precision_1: 0.9300 - recall_1: 0.9302 - val_accuracy: 0.9351 - val_auc_1: 0.9402 - val_loss: 0.2512 - val_mean_io_u_1: 0.5146 - val_precision_1: 0.7176 - val_recall_1: 0.6672
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 524ms/step - accuracy: 0.9872 - auc_1: 0.9979 - loss: 0.0380 - mean_io_u_1: 0.5591 - precision_1: 0.9393 - recall_1: 0.9330 - val_accuracy: 0.9359 - val_auc_1: 0.9398 - val_loss: 0.2582 - val_mean_io_u_1: 0.5184 - val_precision_1: 0.7221 - val_recall_1: 0.6704
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 523ms/step - accuracy: 0.9866 - auc_1: 0.9977 - loss: 0.0392 - mean_io_u_1: 0.5640 - precision_1: 0.9416 - recall_1: 0.9288 - val_accuracy: 0.9338 - val_auc_1: 0.9507 - val_loss: 0.2703 - val_mean_io_u_1: 0.5275 - val_precision_1: 0.6768 - val_recall_1: 0.7516
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 531ms/step - accuracy: 0.9869 - auc_1: 0.9981 - loss: 0.0377 - mean_io_u_1: 0.5622 - precision_1: 0.9399 - recall_1: 0.9350 - val_accuracy: 0.9363 - val_auc_1: 0.9394 - val_loss: 0.2941 - val_mean_io_u_1: 0.5498 - val_precision_1: 0.7084 - val_recall_1: 0.7063
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 527ms/step - accuracy: 0.9865 - auc_1: 0.9974 - loss: 0.0389 - mean_io_u_1: 0.5699 - precision_1: 0.9408 - recall_1: 0.9251 - val_accuracy: 0.9373 - val_auc_1: 0.9462 - val_loss: 0.2632 - val_mean_io_u_1: 0.5335 - val_precision_1: 0.7137 - val_recall_1: 0.7092
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 527ms/step - accuracy: 0.9882 - auc_1: 0.9979 - loss: 0.0355 - mean_io_u_1: 0.5770 - precision_1: 0.9515 - recall_1: 0.9256 - val_accuracy: 0.9359 - val_auc_1: 0.9362 - val_loss: 0.2756 - val_mean_io_u_1: 0.5170 - val_precision_1: 0.7237 - val_recall_1: 0.6668
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 534ms/step - accuracy: 0.9864 - auc_1: 0.9977 - loss: 0.0397 - mean_io_u_1: 0.5759 - precision_1: 0.9276 - recall_1: 0.9382 - val_accuracy: 0.9356 - val_auc_1: 0.9411 - val_loss: 0.2504 - val_mean_io_u_1: 0.5100 - val_precision_1: 0.7279 - val_recall_1: 0.6544
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 547ms/step - accuracy: 0.9883 - auc_1: 0.9980 - loss: 0.0351 - mean_io_u_1: 0.5788 - precision_1: 0.9401 - recall_1: 0.9401 - val_accuracy: 0.9375 - val_auc_1: 0.9328 - val_loss: 0.2722 - val_mean_io_u_1: 0.5285 - val_precision_1: 0.7575 - val_recall_1: 0.6278
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 536ms/step - accuracy: 0.9881 - auc_1: 0.9983 - loss: 0.0344 - mean_io_u_1: 0.5777 - precision_1: 0.9504 - recall_1: 0.9382 - val_accuracy: 0.9354 - val_auc_1: 0.9514 - val_loss: 0.3156 - val_mean_io_u_1: 0.5673 - val_precision_1: 0.6849 - val_recall_1: 0.7551
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 512ms/step - accuracy: 0.9880 - auc_1: 0.9982 - loss: 0.0353 - mean_io_u_1: 0.5852 - precision_1: 0.9421 - recall_1: 0.9418 - val_accuracy: 0.9374 - val_auc_1: 0.9454 - val_loss: 0.2828 - val_mean_io_u_1: 0.5435 - val_precision_1: 0.7138 - val_recall_1: 0.7113
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 539ms/step - accuracy: 0.9874 - auc_1: 0.9979 - loss: 0.0357 - mean_io_u_1: 0.5775 - precision_1: 0.9529 - recall_1: 0.9303 - val_accuracy: 0.9330 - val_auc_1: 0.9476 - val_loss: 0.3132 - val_mean_io_u_1: 0.5543 - val_precision_1: 0.6796 - val_recall_1: 0.7302
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 540ms/step - accuracy: 0.9883 - auc_1: 0.9982 - loss: 0.0344 - mean_io_u_1: 0.5941 - precision_1: 0.9385 - recall_1: 0.9420 - val_accuracy: 0.9362 - val_auc_1: 0.9442 - val_loss: 0.2809 - val_mean_io_u_1: 0.5381 - val_precision_1: 0.7034 - val_recall_1: 0.7173
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 511ms/step - accuracy: 0.9894 - auc_1: 0.9986 - loss: 0.0308 - mean_io_u_1: 0.5893 - precision_1: 0.9478 - recall_1: 0.9524 - val_accuracy: 0.9371 - val_auc_1: 0.9452 - val_loss: 0.2972 - val_mean_io_u_1: 0.5500 - val_precision_1: 0.7190 - val_recall_1: 0.6941
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 525ms/step - accuracy: 0.9900 - auc_1: 0.9988 - loss: 0.0292 - mean_io_u_1: 0.6022 - precision_1: 0.9614 - recall_1: 0.9395 - val_accuracy: 0.9367 - val_auc_1: 0.9408 - val_loss: 0.3095 - val_mean_io_u_1: 0.5552 - val_precision_1: 0.7180 - val_recall_1: 0.6913
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 535ms/step - accuracy: 0.9896 - auc_1: 0.9988 - loss: 0.0299 - mean_io_u_1: 0.6094 - precision_1: 0.9414 - recall_1: 0.9561 - val_accuracy: 0.9372 - val_auc_1: 0.9397 - val_loss: 0.2789 - val_mean_io_u_1: 0.5262 - val_precision_1: 0.7257 - val_recall_1: 0.6823
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 541ms/step - accuracy: 0.9909 - auc_1: 0.9991 - loss: 0.0267 - mean_io_u_1: 0.6097 - precision_1: 0.9579 - recall_1: 0.9555 - val_accuracy: 0.9380 - val_auc_1: 0.9296 - val_loss: 0.3165 - val_mean_io_u_1: 0.5626 - val_precision_1: 0.7349 - val_recall_1: 0.6752
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 521ms/step - accuracy: 0.9907 - auc_1: 0.9989 - loss: 0.0274 - mean_io_u_1: 0.6116 - precision_1: 0.9643 - recall_1: 0.9443 - val_accuracy: 0.9369 - val_auc_1: 0.9423 - val_loss: 0.3037 - val_mean_io_u_1: 0.5522 - val_precision_1: 0.7078 - val_recall_1: 0.7169
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 521ms/step - accuracy: 0.9910 - auc_1: 0.9989 - loss: 0.0268 - mean_io_u_1: 0.6199 - precision_1: 0.9549 - recall_1: 0.9534 - val_accuracy: 0.9368 - val_auc_1: 0.9430 - val_loss: 0.3104 - val_mean_io_u_1: 0.5538 - val_precision_1: 0.7107 - val_recall_1: 0.7088
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 519ms/step - accuracy: 0.9897 - auc_1: 0.9988 - loss: 0.0298 - mean_io_u_1: 0.6093 - precision_1: 0.9432 - recall_1: 0.9531 - val_accuracy: 0.9378 - val_auc_1: 0.9438 - val_loss: 0.3157 - val_mean_io_u_1: 0.5613 - val_precision_1: 0.7182 - val_recall_1: 0.7065
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 539ms/step - accuracy: 0.9889 - auc_1: 0.9987 - loss: 0.0312 - mean_io_u_1: 0.6026 - precision_1: 0.9538 - recall_1: 0.9451 - val_accuracy: 0.9356 - val_auc_1: 0.9361 - val_loss: 0.2823 - val_mean_io_u_1: 0.5281 - val_precision_1: 0.7222 - val_recall_1: 0.6651
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 521ms/step - accuracy: 0.9906 - auc_1: 0.9990 - loss: 0.0271 - mean_io_u_1: 0.6042 - precision_1: 0.9667 - recall_1: 0.9421 - val_accuracy: 0.9354 - val_auc_1: 0.9424 - val_loss: 0.2968 - val_mean_io_u_1: 0.5334 - val_precision_1: 0.7119 - val_recall_1: 0.6850
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 520ms/step - accuracy: 0.9911 - auc_1: 0.9990 - loss: 0.0261 - mean_io_u_1: 0.6236 - precision_1: 0.9593 - recall_1: 0.9542 - val_accuracy: 0.9370 - val_auc_1: 0.9331 - val_loss: 0.2955 - val_mean_io_u_1: 0.5335 - val_precision_1: 0.7348 - val_recall_1: 0.6604
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 539ms/step - accuracy: 0.9920 - auc_1: 0.9993 - loss: 0.0235 - mean_io_u_1: 0.6308 - precision_1: 0.9629 - recall_1: 0.9604 - val_accuracy: 0.9352 - val_auc_1: 0.9447 - val_loss: 0.3321 - val_mean_io_u_1: 0.5588 - val_precision_1: 0.6903 - val_recall_1: 0.7364
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 548ms/step - accuracy: 0.9917 - auc_1: 0.9992 - loss: 0.0242 - mean_io_u_1: 0.6360 - precision_1: 0.9598 - recall_1: 0.9620 - val_accuracy: 0.9351 - val_auc_1: 0.9217 - val_loss: 0.3306 - val_mean_io_u_1: 0.5536 - val_precision_1: 0.7203 - val_recall_1: 0.6618
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 512ms/step - accuracy: 0.9906 - auc_1: 0.9990 - loss: 0.0267 - mean_io_u_1: 0.6258 - precision_1: 0.9659 - recall_1: 0.9433 - val_accuracy: 0.9351 - val_auc_1: 0.9262 - val_loss: 0.3006 - val_mean_io_u_1: 0.5353 - val_precision_1: 0.7365 - val_recall_1: 0.6299
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 539ms/step - accuracy: 0.9915 - auc_1: 0.9991 - loss: 0.0246 - mean_io_u_1: 0.6303 - precision_1: 0.9681 - recall_1: 0.9474 - val_accuracy: 0.9363 - val_auc_1: 0.9319 - val_loss: 0.3258 - val_mean_io_u_1: 0.5557 - val_precision_1: 0.7129 - val_recall_1: 0.6967
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 543ms/step - accuracy: 0.9917 - auc_1: 0.9993 - loss: 0.0238 - mean_io_u_1: 0.6298 - precision_1: 0.9549 - recall_1: 0.9670 - val_accuracy: 0.9361 - val_auc_1: 0.9374 - val_loss: 0.3015 - val_mean_io_u_1: 0.5421 - val_precision_1: 0.7159 - val_recall_1: 0.6870
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 523ms/step - accuracy: 0.9922 - auc_1: 0.9993 - loss: 0.0231 - mean_io_u_1: 0.6442 - precision_1: 0.9603 - recall_1: 0.9596 - val_accuracy: 0.9369 - val_auc_1: 0.9366 - val_loss: 0.3007 - val_mean_io_u_1: 0.5363 - val_precision_1: 0.7243 - val_recall_1: 0.6800
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 521ms/step - accuracy: 0.9930 - auc_1: 0.9994 - loss: 0.0209 - mean_io_u_1: 0.6450 - precision_1: 0.9643 - recall_1: 0.9645 - val_accuracy: 0.9362 - val_auc_1: 0.9367 - val_loss: 0.3200 - val_mean_io_u_1: 0.5485 - val_precision_1: 0.7088 - val_recall_1: 0.7046
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 519ms/step - accuracy: 0.9929 - auc_1: 0.9995 - loss: 0.0208 - mean_io_u_1: 0.6438 - precision_1: 0.9639 - recall_1: 0.9688 - val_accuracy: 0.9368 - val_auc_1: 0.9401 - val_loss: 0.3477 - val_mean_io_u_1: 0.5765 - val_precision_1: 0.7030 - val_recall_1: 0.7280
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 552ms/step - accuracy: 0.9934 - auc_1: 0.9995 - loss: 0.0197 - mean_io_u_1: 0.6527 - precision_1: 0.9662 - recall_1: 0.9679 - val_accuracy: 0.9370 - val_auc_1: 0.9337 - val_loss: 0.3206 - val_mean_io_u_1: 0.5523 - val_precision_1: 0.7190 - val_recall_1: 0.6925
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 513ms/step - accuracy: 0.9934 - auc_1: 0.9995 - loss: 0.0196 - mean_io_u_1: 0.6512 - precision_1: 0.9723 - recall_1: 0.9631 - val_accuracy: 0.9366 - val_auc_1: 0.9360 - val_loss: 0.3543 - val_mean_io_u_1: 0.5693 - val_precision_1: 0.7036 - val_recall_1: 0.7234
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 523ms/step - accuracy: 0.9926 - auc_1: 0.9994 - loss: 0.0214 - mean_io_u_1: 0.6453 - precision_1: 0.9677 - recall_1: 0.9622 - val_accuracy: 0.9356 - val_auc_1: 0.9298 - val_loss: 0.3260 - val_mean_io_u_1: 0.5473 - val_precision_1: 0.7137 - val_recall_1: 0.6843
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 531ms/step - accuracy: 0.9931 - auc_1: 0.9994 - loss: 0.0204 - mean_io_u_1: 0.6541 - precision_1: 0.9668 - recall_1: 0.9646 - val_accuracy: 0.9366 - val_auc_1: 0.9326 - val_loss: 0.3290 - val_mean_io_u_1: 0.5578 - val_precision_1: 0.7133 - val_recall_1: 0.7004
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 546ms/step - accuracy: 0.9932 - auc_1: 0.9995 - loss: 0.0195 - mean_io_u_1: 0.6551 - precision_1: 0.9658 - recall_1: 0.9702 - val_accuracy: 0.9374 - val_auc_1: 0.9215 - val_loss: 0.3395 - val_mean_io_u_1: 0.5644 - val_precision_1: 0.7360 - val_recall_1: 0.6635
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 524ms/step - accuracy: 0.9934 - auc_1: 0.9994 - loss: 0.0192 - mean_io_u_1: 0.6643 - precision_1: 0.9756 - recall_1: 0.9585 - val_accuracy: 0.9362 - val_auc_1: 0.9303 - val_loss: 0.3241 - val_mean_io_u_1: 0.5397 - val_precision_1: 0.7140 - val_recall_1: 0.6915
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 535ms/step - accuracy: 0.9931 - auc_1: 0.9993 - loss: 0.0202 - mean_io_u_1: 0.6651 - precision_1: 0.9687 - recall_1: 0.9621 - val_accuracy: 0.9354 - val_auc_1: 0.9358 - val_loss: 0.3771 - val_mean_io_u_1: 0.5892 - val_precision_1: 0.6963 - val_recall_1: 0.7232
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 528ms/step - accuracy: 0.9921 - auc_1: 0.9991 - loss: 0.0227 - mean_io_u_1: 0.6505 - precision_1: 0.9682 - recall_1: 0.9579 - val_accuracy: 0.9131 - val_auc_1: 0.7541 - val_loss: 0.4547 - val_mean_io_u_1: 0.4740 - val_precision_1: 0.7890 - val_recall_1: 0.2770
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 509ms/step - accuracy: 0.9829 - auc_1: 0.9930 - loss: 0.0493 - mean_io_u_1: 0.5952 - precision_1: 0.9411 - recall_1: 0.8892 - val_accuracy: 0.9255 - val_auc_1: 0.9360 - val_loss: 0.4612 - val_mean_io_u_1: 0.6082 - val_precision_1: 0.6350 - val_recall_1: 0.7459

# %% [markdown]
# ## Visualize predictions

# %%
# Generate predictions for all images in the validation set
val_preds = model.predict(X_test)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step

# %%
preds = val_preds
preds[preds > 0.50] = 1
preds[preds <= 0.50] = 0
sklearn.metrics.accuracy_score(y_test.flatten(), preds.flatten())
# Out:
# 0.9228709992908296

# %%
preds = val_preds
preds[preds > 0.50] = 1
preds[preds <= 0.50] = 0
sklearn.metrics.f1_score(y_test.flatten(), preds.flatten())
# Out:
# 0.6390294703999524

# %%
n = 10  # sample number
fig, ax = plt.subplots(1, 3, figsize=(18, 6))
im1 = ax[0].imshow(
    val_preds[n, :, :, :3].transpose((0, 1, 2)), vmin=0, vmax=1.0, cmap="plasma"
)
im2 = ax[1].imshow(y_test[n, :, :, 0], cmap="plasma")

ax[2].imshow(X_test[n, :, :, :3].transpose((0, 1, 2)))

ax[0].ticklabel_format(useOffset=False, style="plain")
ax[1].ticklabel_format(useOffset=False, style="plain")
ax[2].ticklabel_format(useOffset=False, style="plain")

ax[0].set_title("Predicted")
ax[1].set_title("Ground Truth")
ax[2].set_title("Image")

# fig.colorbar(im1, ax=ax[0])
# fig.colorbar(im2, ax=ax[1])
# Out:
# Text(0.5, 1.0, 'Image')
